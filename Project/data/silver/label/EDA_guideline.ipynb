# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Data/dataset_merged.csv')

# %%
df.head()
# Out:
#   platform     video_id                                    video_url  \
# 0  youtube  5Augh75jX6g  https://www.youtube.com/watch?v=5Augh75jX6g
# 1  youtube  5Augh75jX6g  https://www.youtube.com/watch?v=5Augh75jX6g
# 2  youtube  5Augh75jX6g  https://www.youtube.com/watch?v=5Augh75jX6g
# 3  youtube  5Augh75jX6g  https://www.youtube.com/watch?v=5Augh75jX6g
# 4  youtube  5Augh75jX6g  https://www.youtube.com/watch?v=5Augh75jX6g
#
#                          video_title  \
# 0  HIGHLIGHTS: ARSENAL - BOURNEMOUTH
# 1  HIGHLIGHTS: ARSENAL - BOURNEMOUTH
# 2  HIGHLIGHTS: ARSENAL - BOURNEMOUTH
# 3  HIGHLIGHTS: ARSENAL - BOURNEMOUTH
# 4  HIGHLIGHTS: ARSENAL - BOURNEMOUTH
#
#                                   video_core_content  \
# 0  Diễn biến trận đấu kịch tính giữa Arsenal và B...
# 1  Diễn biến trận đấu kịch tính giữa Arsenal và B...
# 2  Diễn biến trận đấu kịch tính giữa Arsenal và B...
# 3  Diễn biến trận đấu kịch tính giữa Arsenal và B...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10049 entries, 0 to 10048
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   platform                10049 non-null  object
#  1   video_id                10049 non-null  object
#  2   video_url               10049 non-null  object
#  3   video_title             10049 non-null  object
#  4   video_core_content      10049 non-null  object
#  5   video_key_highlights    9416 non-null   object
#  6   video_target_sentiment  10049 non-null  object
#  7   video_cultural_context  3166 non-null   object
#  8   uploader                4057 non-null   object
#  9   upload_date             4057 non-null   float64
#  10  view_count              4057 non-null   float64
#  11  like_count              4057 non-null   float64
#  12  comment_count           4057 non-null   float64
#  13  share_count             4057 non-null   float64
# ...

# %%
df.describe()
# Out:
#         upload_date    view_count     like_count  comment_count  \
# count  4.057000e+03  4.057000e+03    4057.000000    4057.000000
# mean   2.026040e+07  2.509880e+06  177587.305891    1253.019473
# std    3.069781e+01  1.894817e+06  133753.053806    1003.660996
# min    2.026032e+07  4.425000e+05   49300.000000     307.000000
# 25%    2.026041e+07  1.100000e+06   86400.000000     599.000000
# 50%    2.026041e+07  1.900000e+06  121500.000000     823.000000
# 75%    2.026042e+07  2.900000e+06  214200.000000    2760.000000
# max    2.026042e+07  6.300000e+06  454600.000000    3158.000000
#
#          share_count  duration_seconds    comment_id  comment_author_id  \
# count    4057.000000       4057.000000  4.057000e+03       4.057000e+03
# mean    53521.050037         41.997042  7.627934e+18       6.967885e+18
# std     30701.305612         39.461151  2.541074e+15       9.567223e+17
# min      5520.000000         10.000000  7.619512e+18       1.560616e+07
# ...
