# %%
import pandas as pd

# %%
PhoBERT = pd.read_csv("test_result_PhoBERT.csv")
SVM = pd.read_csv("test_result_SVM.csv")
XLM_RoBERTa = pd.read_csv("test_result_XLM_Roberta.csv")

# %%
PhoBERT.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 796 entries, 0 to 795
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   platform                796 non-null    object
#  1   video_id                796 non-null    object
#  2   video_url               796 non-null    object
#  3   video_title             796 non-null    object
#  4   video_core_content      796 non-null    object
#  5   video_target_sentiment  796 non-null    object
#  6   video_highlight         796 non-null    object
#  7   comment                 796 non-null    object
#  8   commonsense             787 non-null    object
#  9   sarcasm_label           796 non-null    object
#  10  sarcasm_type            58 non-null     object
#  11  reasoning               796 non-null    object
#  12  final_label             796 non-null    object
#  13  label                   796 non-null    int64
# ...

# %%
PhoBERT.dropna(subset=["commonsense"], inplace=True, how="any")
SVM.dropna(subset=["commonsense"], inplace=True, how="any")
XLM_RoBERTa.dropna(subset=["commonsense"], inplace=True, how="any")

# %%
PhoBERT.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 787 entries, 0 to 795
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   platform                787 non-null    object
#  1   video_id                787 non-null    object
#  2   video_url               787 non-null    object
#  3   video_title             787 non-null    object
#  4   video_core_content      787 non-null    object
#  5   video_target_sentiment  787 non-null    object
#  6   video_highlight         787 non-null    object
#  7   comment                 787 non-null    object
#  8   commonsense             787 non-null    object
#  9   sarcasm_label           787 non-null    object
#  10  sarcasm_type            58 non-null     object
#  11  reasoning               787 non-null    object
#  12  final_label             787 non-null    object
#  13  label                   787 non-null    int64
# ...

# %%
XLM_RoBERTa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 787 entries, 0 to 795
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   platform                787 non-null    object
#  1   video_id                787 non-null    object
#  2   video_url               787 non-null    object
#  3   video_title             787 non-null    object
#  4   video_core_content      787 non-null    object
#  5   video_target_sentiment  787 non-null    object
#  6   video_highlight         787 non-null    object
#  7   comment                 787 non-null    object
#  8   commonsense             787 non-null    object
#  9   sarcasm_label           787 non-null    object
#  10  sarcasm_type            58 non-null     object
#  11  reasoning               787 non-null    object
#  12  final_label             787 non-null    object
#  13  label                   787 non-null    int64
# ...

# %%
SVM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 787 entries, 0 to 795
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   platform                787 non-null    object
#  1   video_id                787 non-null    object
#  2   video_url               787 non-null    object
#  3   video_title             787 non-null    object
#  4   video_core_content      787 non-null    object
#  5   video_target_sentiment  787 non-null    object
#  6   video_highlight         787 non-null    object
#  7   comment                 787 non-null    object
#  8   commonsense             787 non-null    object
#  9   sarcasm_label           787 non-null    object
#  10  sarcasm_type            58 non-null     object
#  11  reasoning               787 non-null    object
#  12  final_label             787 non-null    object
#  13  predicted_label         787 non-null    object
# ...

# %%
SVM.to_csv("test_result_SVM_clean.csv", index=False)
PhoBERT.to_csv("test_result_PhoBERT_clean.csv", index=False)
XLM_RoBERTa.to_csv("test_result_XLM_Roberta_clean.csv", index=False)
